# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
msd="https://www.imdb.com/list/ls003722628/"

# %%
response=requests.get(msd)

# %%
response
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(response.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>top 50 tamil movies of all time to be watched before you die - IMDb</title>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>
#     if (typeof uex == 'function') {
#       uex("ld", "LoadTitle", {wb: 1});
#     }
# </script>
# <link href="https://www.imdb.com/list/ls003722628/" rel="canonical"/>
# ...

# %%
name=soup.select(".lister-item-header a")

# %%
name
# Out:
# [<a href="/title/tt0367495/">Anbe Sivam</a>,
#  <a href="/title/tt0234697/">Server Sundaram</a>,
#  <a href="/title/tt0312859/">Kannathil Muthamittal</a>,
#  <a href="/title/tt0140090/">Guna</a>,
#  <a href="/title/tt0101649/">Thalapathi</a>,
#  <a href="/title/tt0154462/">Ethir Neechal</a>,
#  <a href="/title/tt0105271/">Roja</a>,
#  <a href="/title/tt0234571/">Ratha Kanneer</a>,
#  <a href="/title/tt0105575/">Thevar Magan</a>,
#  <a href="/title/tt1547442/">Aayirathil Oruvan</a>,
#  <a href="/title/tt0091559/">Mouna Ragam</a>,
#  <a href="/title/tt0274026/">Raaja Paarvai</a>,
#  <a href="/title/tt1431155/">Sumaithangi</a>,
#  <a href="/title/tt0116630/">Indian</a>,
#  <a href="/title/tt0187318/">Moondram Pirai</a>,
#  <a href="/title/tt0140348/">Mahanadhi</a>,
#  <a href="/title/tt0140448/">Pathinaru Vayathinile</a>,
#  <a href="/title/tt0089646/">Muthal Mariyathai</a>,
#  <a href="/title/tt0096827/">Apoorva Sagodharargal</a>,
#  <a href="/title/tt0215033/">Parasakthi</a>,
# ...

# %%
rating=soup.select(".ipl-rating-star.small .ipl-rating-star__rating")

# %%
rating
# Out:
# [<span class="ipl-rating-star__rating">8.6</span>,
#  <span class="ipl-rating-star__rating">7.9</span>,
#  <span class="ipl-rating-star__rating">8.4</span>,
#  <span class="ipl-rating-star__rating">8.2</span>,
#  <span class="ipl-rating-star__rating">8.5</span>,
#  <span class="ipl-rating-star__rating">8.3</span>,
#  <span class="ipl-rating-star__rating">8.1</span>,
#  <span class="ipl-rating-star__rating">8.5</span>,
#  <span class="ipl-rating-star__rating">8.7</span>,
#  <span class="ipl-rating-star__rating">6.5</span>,
#  <span class="ipl-rating-star__rating">8.4</span>,
#  <span class="ipl-rating-star__rating">7.7</span>,
#  <span class="ipl-rating-star__rating">7.1</span>,
#  <span class="ipl-rating-star__rating">8.1</span>,
#  <span class="ipl-rating-star__rating">8.6</span>,
#  <span class="ipl-rating-star__rating">8.6</span>,
#  <span class="ipl-rating-star__rating">8</span>,
#  <span class="ipl-rating-star__rating">7.8</span>,
# ...

# %%
year=soup.select(".text-muted.unbold")

# %%
year
# Out:
# [<legend class="text-muted unbold" data-tag="IMDb Rating">IMDb user rating (average)</legend>,
#  <legend class="text-muted unbold" data-tag="Votes">Number of votes</legend>,
#  <legend class="text-muted unbold" data-tag="Released">Release year or range</legend>,
#  <span class="lister-item-year text-muted unbold">(2003)</span>,
#  <span class="lister-item-year text-muted unbold">(1964)</span>,
#  <span class="lister-item-year text-muted unbold">(2002)</span>,
#  <span class="lister-item-year text-muted unbold">(1991)</span>,
#  <span class="lister-item-year text-muted unbold">(1991)</span>,
#  <span class="lister-item-year text-muted unbold">(1968)</span>,
#  <span class="lister-item-year text-muted unbold">(1992)</span>,
#  <span class="lister-item-year text-muted unbold">(1954)</span>,
#  <span class="lister-item-year text-muted unbold">(1992)</span>,
#  <span class="lister-item-year text-muted unbold">(2009)</span>,
# ...

# %%
votes=soup.select(".text-small+ .text-small")

# %%
votes
# Out:
# [<p class="text-muted text-small">
#  <span class="text-muted">Votes:</span>
#  <span data-value="23816" name="nv">23,816</span>
#  </p>,
#  <p class="text-muted text-small">
#  <span class="text-muted">Votes:</span>
#  <span data-value="341" name="nv">341</span>
#  </p>,
#  <p class="text-muted text-small">
#  <span class="text-muted">Votes:</span>
#  <span data-value="8787" name="nv">8,787</span>
#  </p>,
#  <p class="text-muted text-small">
#  <span class="text-muted">Votes:</span>
#  <span data-value="2844" name="nv">2,844</span>
#  </p>,
#  <p class="text-muted text-small">
#  <span class="text-muted">Votes:</span>
#  <span data-value="12618" name="nv">12,618</span>
#  </p>,
#  <p class="text-muted text-small">
#  <span class="text-muted">Votes:</span>
#  <span data-value="470" name="nv">470</span>
#  </p>,
#  <p class="text-muted text-small">
#  <span class="text-muted">Votes:</span>
#  <span data-value="13189" name="nv">13,189</span>
#  </p>,
# ...

# %%
import pandas

# %%
name=pandas.DataFrame(name,columns=['movie name'])

# %%
name
# Out:
#                      movie name
# 0                    Anbe Sivam
# 1               Server Sundaram
# 2         Kannathil Muthamittal
# 3                          Guna
# 4                    Thalapathi
# 5                 Ethir Neechal
# 6                          Roja
# 7                 Ratha Kanneer
# 8                  Thevar Magan
# 9             Aayirathil Oruvan
# 10                  Mouna Ragam
# 11                Raaja Paarvai
# 12                  Sumaithangi
# 13                       Indian
# 14               Moondram Pirai
# 15                    Mahanadhi
# 16        Pathinaru Vayathinile
# 17            Muthal Mariyathai
# 18        Apoorva Sagodharargal
# 19                   Parasakthi
# 20                       Anjali
# 21         Unnal Mudiyum Thambi
# 22                        Sethu
# 23                Amaidhi Padai
# 24                      Azhakan
# 25  Chinna Thambi Periya Thambi
# 26                   Aan Paavam
# 27            Agni Natchathiram
# ...

# %%
name["rating"]=rating

# %%
name["votes"]=votes

# %%
name
# Out:
#                      movie name rating                             votes
# 0                    Anbe Sivam  [8.6]  [\n, [Votes:], \n, [23,816], \n]
# 1               Server Sundaram  [7.9]     [\n, [Votes:], \n, [341], \n]
# 2         Kannathil Muthamittal  [8.4]   [\n, [Votes:], \n, [8,787], \n]
# 3                          Guna  [8.2]   [\n, [Votes:], \n, [2,844], \n]
# 4                    Thalapathi  [8.5]  [\n, [Votes:], \n, [12,618], \n]
# 5                 Ethir Neechal  [8.3]     [\n, [Votes:], \n, [470], \n]
# 6                          Roja  [8.1]  [\n, [Votes:], \n, [13,189], \n]
# 7                 Ratha Kanneer  [8.5]     [\n, [Votes:], \n, [349], \n]
# 8                  Thevar Magan  [8.7]   [\n, [Votes:], \n, [7,468], \n]
# 9             Aayirathil Oruvan  [6.5]     [\n, [Votes:], \n, [164], \n]
# 10                  Mouna Ragam  [8.4]   [\n, [Votes:], \n, [4,070], \n]
# 11                Raaja Paarvai  [7.7]     [\n, [Votes:], \n, [247], \n]
# ...

# %%
name.to_csv("C:\\Users\\aedpu\\OneDrive\\Documents\\madhu.csv")
